# %% [markdown]
# # La collecte automatique de données sur le Web

# %% [markdown]
# Avant de commencer à nous attaquer à de belles pages web (html), nous allons decouvrir le langage xml qui est une bonne introduction au data web scraping

# %% [markdown]
# ### Le XML

# %% [markdown]
# Le XML a été créé pour faciliter les échanges de données entre les machines et les logiciels.
#
# Le XML est un langage qui s'écrit à l'aide de balises.
#
# Le XML est une recommandation du W3C, il s'agit donc d'une technologie avec des règles strictes à respecter.
#
# Le XML se veut compréhensible par tous : les hommes comme les machines.
#
# Le XML nous permet de créer notre propre vocabulaire grâce à un ensemble de règles et de balises personnalisables.

# %% [markdown]
# Le XML se veut également compatible avec le web afin que les échanges de données puissent se faire facilement à travers le réseau Internet.
#
# Le XML se veut donc standardisé, simple, mais surtout extensible et configurable afin que n'importe quel type de données puisse être décrit.

# %% [markdown]
# Voici un exemple de document XML, que nous avons enregistré sous le nom de data.xml dans le repertoire data
#
# Affichez son contenu

# %%
fichier = open("data/data.xml", "r")
print (fichier.read())
fichier.close()
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <users>
#     <user data-id="101">
#         <nom>Zorro</nom>
#         <metier>Danseur</metier>
#     </user>
#     <user data-id="102">
#         <nom>Hulk</nom>
#         <metier>Footballeur</metier>
#     </user>
#     <user data-id="103">
#         <nom>Zidane</nom>
#         <metier>Star</metier>
#     </user>
#     <user data-id="104">
#         <nom>Beans</nom>
#         <metier>Epicier</metier>
#     </user>
#     <user data-id="105">
#         <nom>Batman</nom>
#         <metier>Veterinaire</metier>
#     </user>
#     <user data-id="106">
#         <nom>Spiderman</nom>
#         <metier>Veterinaire</metier>
#     </user>
# </users>

# %% [markdown]
# La première ligne indique l' encodage , on reste toujours dans l' encodage UTF-8 . Ensuite on remarque que la balise "users" possède d'autres balises "user" qui elles même possèdent leurs propres balises. Les données sont hiérarchisées dans un arbre et chaque noeud apporte une information.

# %% [markdown]
# Voici un petit script qui affiche tous les noms des user .

# %%
from lxml import etree
# Je definis mon document source
tree = etree.parse("data/data.xml")
# je regarde mon document et j'identifie le chemin de balise pour arriver à l'information "user"
# En effet, l'information se trouve dans une balise nom elle meme presente dans une balise user
# elle meme presente dans une balise users. Cette derniere balise se trouvant à la racine du repertoire
# donc dans tree.xpath("/users/user/nom") il y a les balises associées à notre recherche
for user in tree.xpath("/users/user/metier"):
    # Je souhaite afficher uniquement le contenu (.text) de ces balises /users/user/nom
    print(user.text)
# Out:
# Danseur
# Footballeur
# Star
# Epicier
# Veterinaire
# Veterinaire

# %%
tree.xpath("/users/user/nom")[4].text
# Out:
# 'Batman'

# %%
#Vous pouvez afficher les attributs des balises qui stocke ces informations
tree = etree.parse("data/data.xml")
for user in tree.xpath("/users/user"):
    print(user.get("data-id"))
# Out:
# 101
# 102
# 103
# 104
# 105
# 106

# %% [markdown]
# Vous pouvez affiner l'affichage en proposant de n'afficher que les user dont le métier est Veterinaire

# %%
tree = etree.parse("data/data.xml")
# Quel joli petit dictionnaire
for user in tree.xpath("/users/user[metier='Veterinaire']/nom"):
    print(user.text)

# %% [markdown]
# # Data web scrapping

# %% [markdown]
# Nous avons vu précédemment comment parser du XML , il est également possible de parser du HTML et l'outil qui fait le mieux le job selon moi c'est le librairy BeautifulSoup

# %% [markdown]
# Enregistrer une page web (par exemple lequipe.fr) que vous aimez bien dans le repertoire data, et afficher son contenu (le fichier xxx.html)
#
# Mettez le contenu de cette page dans une variable, par exemple html_doc

# %%
fichier = open("data/L'ÉQUIPE - L'actualité du sport en continu..html", "r")
#print(fichier.read())
html_doc=fichier.read()
fichier.close()
html_doc
# Out:
# '<!DOCTYPE html>\n<!-- saved from url=(0023)https://www.lequipe.fr/ -->\n<html tpl="v7/home" class=""><head><meta http-equiv="Content-Type" content="text/html; charset=UTF-8"><script type="text/javascript" src="./L&#39;ÉQUIPE - L&#39;actualité du sport en continu._files/get" charset="UTF-8" async=""></script><script id="wonderpush-jssdk" src="./L&#39;ÉQUIPE - L&#39;actualité du sport en continu._files/wonderpush.min.js"></script><script type="text/javascript" src="./L&#39;ÉQUIPE - L&#39;actualité du sport en continu._files/get(1)" charset="UTF-8" async=""></script><iframe src="javascript:false" style="width: 0px; height: 0px; border: 0px; display: none;" src="./L&#39;ÉQUIPE - L&#39;actualité du sport en continu._files/saved_resource.html"></iframe><script id="wonderpush-jssdk-loader" src="./L&#39;ÉQUIPE - L&#39;actualité du sport en continu._files/wonderpush-loader.min.js"></script><script src="./L&#39;ÉQUIPE - L&#39;actualité du sport en continu._files/f(7).txt"></script><script type="text/javascript" src="./L&#39;ÉQUIPE - L&#39;actualité du sport en continu._files/get(2)" charset="UTF-8" async=""></script><script type="text/javascript" async="" src="./L&#39;ÉQUIPE - L&#39;actualité du sport en continu._files/on-1.0.min.js"></script><script src="./L&#39;ÉQUIPE - L&#39;actualité du sport en continu._files/pulpix.js" id="pulpix" async="" data-user-id="715"></script><script src="./L&#39;ÉQUIPE - L&#39;actualité du sport en continu._files/pubads_impl_rendering_270.js"></script><script src="./L&#39;ÉQUIPE - L&#39;actualité du sport en continu._files/ps-ut-draw.min.js" async=""></script>\n    \n        <script async="" type="text/javascript" src="./L&#39;ÉQUIPE - L&#39;actualité du sport en continu._files/gpt.js"></script><script type="text/javascript" src="./L&#39;ÉQUIPE - L&#39;actualité du sport en continu._files/rc"></script><script src="./L&#39;ÉQUIPE - L&#39;actualité du sport en continu._files/125278988146629" async=""></script><script async="" src="./L&#39;ÉQUIPE - L&#39;actualité du sport en continu._files/fbevents.js"></script><script type="text/javascript">\n    var kameleoonLoadingTimeout = 1000;\n    var kameleoonStartLoadTime = new Date().getTime();\n    if (! document.getElementById("kameleoonLoadingStyleSheet") && ! window.kameleoonDisplayPageTimeOut){\n        var kameleoonS = document.getElementsByTagName("script")[0];var kameleoonCc = "* { visibility: hidden !important; background-image: none !important; }";\n        var kameleoonStn = document.createElement("style");kameleoonStn.type = "text/css";kameleoonStn.id = "kameleoonLoadingStyleSheet";\n        if (kameleoonStn.styleSheet){kameleoonStn.styleSheet.cssText = kameleoonCc;}else{kameleoonStn.appendChild(document.createTextNode(kameleoonCc));}kameleoonS.parentNode.insertBefore(kameleoonStn, kameleoonS);\n        window.kameleoonDisplayPage = function(){if (kameleoonStn.parentNode){kameleoonStn.parentNode.removeChild(kameleoonStn);}};\n        window.kameleoonDisplayPageTimeOut = window.setTimeout(window.kameleoonDisplayPage, kameleoonLoadingTimeout);}\n</script>\n<script src="./L&#39;ÉQUIPE - L&#39;actualité du sport en continu._files/kameleoon.js" async="true"></script>\n\n    \n    \n\n    \n\n\n\n\n\n\n\n<!-- IDS : 3 -->\n<!-- TYPEPAGE : home_rub -->\n<!-- TAG_EDITO_LIB : general -->\n<!-- www.lequipe.fr --> \n\n  \n\n\n\n\t\t\t\t<script type="text/javascript">\n\n\t\t\t\tcodeweb = \'WTF\';\n\t\t\t\tidtag = \'1\';\n\t\t\t\tsas_pageid=\'2368/17155\';\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\t\t\t\txtn2 = "23"; /* (General) */\n\t\t\t\txtpage = "General::home";\n\n\t\t\t\t</script>\n \n\n\n\n\n            \n            <script>\n                var xtpage = \'General::home\';\n            </script>\n            \n\n            \n            <meta http-equiv="refresh" content="300">\n            \n                <script>\n               ...

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(html_doc)
# Dans mon fichier (lequipe.fr) en regardant ce script html Nous pouvons voir que le titre principal est rangé 
# dans la balise h1
for p in soup.find_all('link'):
    # Nous récupérons uniquement le contenu ==> .text
    print (p.get('href'))
# Out:
# https://www.lequipe.fr/
# https://m.lequipe.fr/
# https://www.lequipe.fr/elements/img/favicons/apple-touch-icon-57x57.png?140917
# https://www.lequipe.fr/elements/img/favicons/apple-touch-icon-60x60.png?140917
# https://www.lequipe.fr/elements/img/favicons/apple-touch-icon-72x72.png?140917
# https://www.lequipe.fr/elements/img/favicons/apple-touch-icon-76x76.png?140917
# https://www.lequipe.fr/elements/img/favicons/apple-touch-icon-114x114.png?140917
# https://www.lequipe.fr/elements/img/favicons/apple-touch-icon-120x120.png?140917
# https://www.lequipe.fr/elements/img/favicons/apple-touch-icon-144x144.png?140917
# https://www.lequipe.fr/elements/img/favicons/apple-touch-icon-152x152.png?140917
# https://www.lequipe.fr/elements/img/favicons/apple-touch-icon-180x180.png?140917
# https://www.lequipe.fr/elements/img/favicons/favicon-32x32.png?140917
# https://www.lequipe.fr/elements/img/favicons/android-chrome-192x192.png?140917
# https://www.lequipe.fr/elements/img/favicons/favicon-96x96.png?140917
# https://www.lequipe.fr/elements/img/favicons/favicon-16x16.png?140917
# https://www.lequipe.fr/elements/img/favicons/manifest.json
# https://www.lequipe.fr/elements/img/favicons/apple-touch-icon-16x16.png
# ./L'ÉQUIPE - L'actualité du sport en continu._files/style-cch-20181026165210.min.css
# ./L'ÉQUIPE - L'actualité du sport en continu._files/widget.css
# ./L'ÉQUIPE - L'actualité du sport en continu._files/f(8).txt
# ./L'ÉQUIPE - L'actualité du sport en continu._files/f(9).txt
# https://tpc.googlesyndication.com/safeframe/1-0-30/html/container.html
# ./L'ÉQUIPE - L'actualité du sport en continu._files/pulpix.css
# https://www.lequipe.fr/elements/img/favicons/manifest.json

# %%
soup = BeautifulSoup(html_doc)
# Dans mon fichier (lequipe.fr) en regardant ce script html Nous pouvons voir que les sous titres sont rangés 
# dans la balise h2
for p in soup.find_all('h1'):
    print (p.text)
# Out:
# Avec la finale de Coupe Davis en tête

# %% [markdown]
# Toujours sur l'equipe.fr, pourrez vous afficher les descriptions d'articles situés sous les sousitre, s'ily en a

# %%
soup = BeautifulSoup(html_doc)

for p in soup.find_all('p'):
    print('####################################""')
    print (p.text.strip())
# Out:
# ####################################""
# Une grosse dizaine de joueurs français peut prétendre à la finale de la Coupe Davis (23-25 novembre). Si pour certains la sélection semble une évidence, pour les autres, le Rolex Paris Masters sera le dernier moment pour se montrer.
# ####################################""
# Anthony Martial a encore régalé ce week-end. Pour Raphaël Varane et Benjamin Pavard, notamment, il a viré au cauchemar.
# ####################################""
# Le carton du Barça lors du Clasico face au Real, la performance de Cristiano Ronaldo avec la Juventus, le choc Naples-Roma, la terrible série de Newcastle, etc. Avez-vous bien suivi le week-end européen ?
# ####################################""
# Auteur de son quatrième but en trois matches de Premier League, l'attaquant français a confirmé son retour en forme.
# ####################################""
# 1€
# ####################################""
# puis 9,99€/mois sans engagement
# ####################################""
# offre valable du 23 au 31 octobre 2018
#                     * voir conditions
# ####################################""
# Adrian mannarino, 46e mondial, entre en lice contre Ugo Humbert, bénéficiaire d'une invitation. A suivre ensuite Richard Gasquet et Nicolas Mahut. Les matches en scoring.
# ####################################""
# Après avoir annoncé la suspension de Régis Brouard comme entraîneur, le Red Star a annoncé lundi l'arrivée de Faruk Hadzibegic.
# ####################################""
# La nouvelle règle des quatre remplacements supplémentaires sur blessure, testée cette saison en Top 14 et Pro D2 afin de protéger la santé des joueurs, «dérange un peu» Jacques Brunel, le sélectionneur du XV de France.
# ####################################""
# La majorité des joueurs français a brillé la semaine dernière en NBA. Avec une mention pour Rudy Gobert et Elie Okobo.
# ####################################""
# Quatre anciens champions du monde évaluent Lewis Hamilton au regard de ses glorieux aînés.
# ####################################""
# Entré en cours de jeu à Marseille (0-2), l'attaquant parisien n'a pas mis longtemps pour signer sa 10e réalisation de la saison. Et asseoir un peu plus sa suprématie au classement des buteurs.
# ####################################""
# Mécontent de ne pas avoir été titularisé à Angers, l'international néerlandais de l'OL payait son attitude à Hoffenheim, mardi, pendant et après le match.
# ####################################""
# Lille et Montpellier restent les lointains poursuivants du PSG, auteur d'un 11e succès en onze matches, à Marseille. En fond de classement, Monaco ne décolle pas. Le bilan du week-end.
# ####################################""
# Dans un entretien accordé à France Football, Cristiano Ronaldo, l'attaquant de la Juventus Turin, a expliqué qu'il avait quitté le Real Madrid, l'été dernier, car il ne se sentait plus considéré.
# ####################################""
# Pour la Route du Rhum, quelques sacs sont embarqués pour répondre à toutes les problématiques.
# ####################################""
# Le Manceau est de retour au Rolex Paris Masters après une saison gâchée par les blessures.
# ####################################""
# Cédric Raynaud, entraîneur d'Ugo Humbert, évoque le premier tour de son jeune joueur contre Adrian Mannarino aujourd'hui.
# ####################################""
# Jack Sock va défendre son titre au Rolex Paris Masters. Une entreprise bien difficile pour un joueur qui n'a remporté que sept matches cette saison.
# ####################################""
# Alors que Toulon et Perpignan restent scotchés en fond de classement, Clermont et le Stade Français continuent de briller. Le bilan du week-end.
# ####################################""
# L'Olympique Lyonnais a grimpé de sept places dans le classement des clubs ayant formé le plus de joueurs actuellement présents dans 31 premières divisions européennes, passant de la 21e à la 14e place. Dans les cinq grands Championnats, le centre de formation de l'OL est deuxième.
# ####################################""
# Chaque lundi, nous déterminons l'équipe type des meilleurs joueurs français du week-end, qu'ils jouent en Ligue 1 ou à l'étranger. Cette semaine, on y retrouve Paul Pogba et Kylian Mbappé, mais aussi Dayot Upamecano, Nicolas Benezet et Sébastien Haller.
# ####################################""
# Le Britannique, sacré champion du monde de F1 pour la cinquième fois, sait aussi s'occuper loin des circuits.
# ####################################""
# Qui a brillé ce dimanche à Mexico ? Qui s'est loupé ? Retrouvez notre carnet de notes du Grand Prix du Mexique... avec plus ou moins de bonne foi.
# ####################################""
# Lewis Hamilton avait du mal à mettre des mots sur ses émotions après une course difficile, dimanche à Mexico, qui s'est conclue par son cinquième titre mondial.
# ####################################""
# Lewis Hamilton a décroché son cinquième titre de champion du monde grâce à sa victoire dimanche à Mexico. Revivez en images la saison du pilote britannique.
# ####################################""
# Jean-Philippe Durand et Mickaël Madar débriefent la victoire du PSG à Marseille (2-0).
# ####################################""
# L'attaquant du PSG, buteur face à Marseille après être entré en jeu, assure être capable d'assumer le rôle de leader.
# ####################################""
# L'entraîneur marseillais peinait à digérer la faute sifflée contre Kevin Strootman, qui a privé son équipe de l'égalisation (86e).
# ####################################""
# Déjà en vue lors du match précédent, Rudy Gobert, avec Utah, et Elie Okobo, avec Phoenix, ont confirmé avec de nouvelles bonnes performances.
# ####################################""
# Golden State a signé une quatrième victoire consécutive, en battant Brooklyn (120-114) dimanche, tandis qu'Oklahoma City a enfin décroché un succès, face à Phoenix (117-110).
# ####################################""
# Toronto et Milwaukee invincibles, Stephen Curry qui claque 51 points, Tyronn Lue congédié à Cleveland... Retrouvez les infos les plus marquantes de la semaine écoulée.
# ####################################""
# Comme chaque lundi, venez voter pour le joueur NBA qui vous a le plus impressionné dans chaque conférence la semaine passée.
# ####################################""
# Le propriétaire de Leicester, Vichai Srivaddhanaprabha, est mort dans l'accident d'hélicoptère survenu samedi, sur le parking du King Power Stadium, après le match contre West Ham.
# ####################################""
# Mal en point en ce début de saison, les Los Angeles Kings et les Detroit Red Wings l'ont emporté, respectivement face aux NY Rangers (4-3) et à Dallas (4-2).
# ####################################""
# A l'issue d'une victoire large (5-1) chez les Los Angeles Dodgers lors du match 5, les Boston Red Sox ont remporté les World Series pour la neuvième fois de leur histoire.
# ####################################""
# Dix mois après leur défaite crève-coeur en play-offs, les New Orleans Saints ont cette fois battu les Minnesota Vikings sur leur terrain (30-20). Les LA Rams sont toujours invaincus.
# ####################################""
# Roger Federer, Lewis Hamilton, Sébastien Loeb, Tessa Worley et Elina Svitolina ont brillé ce week-end. Votez pour celui ou celle qui vous a le plus impressionné.
# ####################################""
# Venu pour une pige, Sébastien Loeb se réjouit de sa victoire en Catalogne. Et n'exclut plus de rempiler la saison prochaine.
# ####################################""
# Le Paris-SG a disposé comme d'habitude de l'OM dans un Classique marqué par les choix forts des deux entraineurs et une grosse erreur d'arbitrage.
# ####################################""
# Le sacre de Brett Rheeder, des tricks de haut vol, le podium avec Andreu Lacondeguy et Ethan Nell... Revivez en images la Red Bull Rampage 2018 dans le désert poussiéreux de l'Utah. La compétition de VTT considérée comme la plus spectaculaire du monde.
# ####################################""
# Si le FC Barcelone et le Real Madrid ont prévu de rénover leurs enceintes de manière significative, d'autres clubs avant eux sont déjà passés à l'acte. Zoom sur les plus belles rénovations de stades.
# ####################################""
# Un peu trop accro au café latte ? Voici notre sélection de boissons healthy et gourmandes, dans lesquelles la caféine est remplacée par de bons nutriments. Une bonne façon de se faire plaisir avec un latte, en apportant de bonnes choses à notre organisme.
# ####################################""
# La MBF (Moutain Bikers Foundation) a réagi au décès d'un vététiste suite à un accident de chasse en proposant des solutions pour améliorer la sécurité des deux parties.
# ####################################""
# Voici notre guide complet des 30  franchises de la NBA, avant le début de la saison régulière, le 16 octobre.
# ####################################""
# Des tribunes pleines, des chants, des cris: le départ de la Ryder Cup se déroule toujours dans une atmosphère indescriptible pour les golfeurs.
# ####################################""
# Découvrez dans ce nouvel Equipe Explore les légendaires matches de Grand Chelem que Roger Federer a disputés pour devenir, sans doute, le plus grand joueur de tous les temps.
# ####################################""
# Ce travail, réalisé par les élèves de l’Ecole de journalisme de Sciences-Po, a remporté le IVe Prix Explore.
# ####################################""
#
# ####################################""
#
# ####################################""
#
# ####################################""
#
# ####################################""

# %% [markdown]
# ### Scrapping en live via une requete HTTP

# %% [markdown]
# HTTP est un espèce de langage qui va permettre au client (vous, par le biais de votre navigateur par exemple) de communiquer avec un serveur connecté au réseau (le serveur HTTP installé sur le serveur d'un site, par exemple Apache).
#
# Les requêtes vont toujours par paires : la demande (du client) et la réponse (du serveur).
# Si ce n'est pas le cas, c'est qu'un problème est survenu à un endroit du réseau.
#
# La syntaxe de la demande (= requête client) est toujours la même :
# - Ligne de commande (Commande, URL, Version de protocole)

# %% [markdown]
# Commande est la méthode à utiliser, il spécifie le type de requête, il peut avoir les valeurs :
#
#
# GET
# C'est la méthode la plus courante pour demander une ressource. Une requête GET est sans effet sur la ressource, il doit être possible de répéter la requête sans effet.
#
# HEAD
# Cette méthode ne demande que des informations sur la ressource, sans demander la ressource elle-même.
#
# POST
# Cette méthode doit être utilisée lorsqu'une requête modifie la ressource.
#
# OPTIONS
# Cette méthode permet d'obtenir les options de communication d'une ressource ou du serveur en général.
#
# CONNECT
# Cette méthode permet d'utiliser un proxy comme un tunnel de communication.
#
# TRACE
# Cette méthode demande au serveur de retourner ce qu'il a reçu, dans le but de tester et d'effectuer un diagnostic sur la connexion.
#
# PUT
# Cette méthode permet d'ajouter une ressource sur le serveur.
#
# DELETE
# Cette méthode permet de supprimer une ressource du serveur.
#
# Je n'aborderai ici que les plus courantes : HEAD, GET et POST.

# %% [markdown]
# ### Concretement

# %%
import requests
# L'url du site à scrapper
url='https://www.lequipe.fr/'
# J'emet ma requet HTTP avec un"GET" au serveur du site identifier dans l'url
r = requests.get(url)
# J'affiche l'url requété ainsi que le retour du serveur
print(url, r.status_code)
# Je demande à beautifulSoup de conserver dans une variable soup la page web à scrapper (url) un script html
soup = BeautifulSoup(r.content,'html')
soup
# Out:
# https://www.lequipe.fr/ 200
# <!DOCTYPE html>
# <html class="" tpl="v7/home">
# <head>
# <script type="text/javascript">
#     var kameleoonLoadingTimeout = 1000;
#     var kameleoonStartLoadTime = new Date().getTime();
#     if (! document.getElementById("kameleoonLoadingStyleSheet") && ! window.kameleoonDisplayPageTimeOut){
#         var kameleoonS = document.getElementsByTagName("script")[0];var kameleoonCc = "* { visibility: hidden !important; background-image: none !important; }";
#         var kameleoonStn = document.createElement("style");kameleoonStn.type = "text/css";kameleoonStn.id = "kameleoonLoadingStyleSheet";
#         if (kameleoonStn.styleSheet){kameleoonStn.styleSheet.cssText = kameleoonCc;}else{kameleoonStn.appendChild(document.createTextNode(kameleoonCc));}kameleoonS.parentNode.insertBefore(kameleoonStn, kameleoonS);
#         window.kameleoonDisplayPage = function(){if (kameleoonStn.parentNode){kameleoonStn.parentNode.removeChild(kameleoonStn);}};
#         window.kameleoonDisplayPageTimeOut = window.setTimeout(window.kameleoonDisplayPage, kameleoonLoadingTimeout);}
# </script>
# <script async="true" src="//static-bp.kameleoon.com/css/customers/xe2jlmuyam/0/kameleoon.js"></script>
# <!-- IDS : 3 -->
# <!-- TYPEPAGE : home_rub -->
# <!-- TAG_EDITO_LIB : general -->
# <!-- www.lequipe.fr -->
# <script type="text/javascript">
#
# 				codeweb = 'WTF';
# 				idtag = '1';
# 				sas_pageid='2368/17155';
#
#
# 				xtn2 = "23"; /* (General) */
# 				xtpage = "General::home";
#
# 				</script>
# <script>
#                 var xtpage = 'General::home';
#             </script>
# <meta content="300" http-equiv="refresh"/>
# <script>
#                     sas_formatids = "2077,2078,2163,630,12340,632,1075,1446,651,646,17532";
#                 </script>
# <script>
#                     var at_typePage = "home";
#                 </script>
# <meta charset="utf-8"/>
# <title>L'ÉQUIPE - L'actualité du sport en continu.</title>
# <meta content="Le sport en direct sur L'EQUIPE.fr. Les informations, résultats et classements de tous les sports. Directs commentés, images et vidéos à regarder et à partager !" name="Description"/>
# <meta content="7" property="version:efr"/>
# <meta content="https://www.lequipe.fr/" itemprop="url"/>
# <meta content="/v7-lequipe/shared/generated/includes/" itemprop="dynamic"/>
# <!-- pas abo -->
# <!-- pas domaine beta -->
# <script src="/elements/js/standalone/detectmobiles.js?2017" type="text/javascript"></script>
# <!-- BEGIN Krux Control Tag for "AMA_LEquipe" -->
# <!-- Source: /snippet/controltag?confid=JJ8luyXM&site=AMA_LEquipe&edit=1 -->
# <!-- Facebook Pixel Code -->
# <script>
#     !function(f,b,e,v,n,t,s)
#     {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#         n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#         if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#         n.queue=[];t=b.createElement(e);t.async=!0;
#         t.src=v;s=b.getElementsByTagName(e)[0];
#         s.parentNode.insertBefore(t,s)}(window, document,'script',
#         'https://connect.facebook.net/en_US/fbevents.js');
#     fbq('init', '125278988146629');
#     fbq('track', 'PageView');
# </script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=125278988146629&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <!-- End Facebook Pixel Code -->
# <meta content="activity_sport" name="object_type"/>
# <!-- "/"  -->
# <link href="https://www.lequipe.fr/" rel="canonical"/>
# <link href="https://m.lequipe.fr/" media="only screen and (max-width: 640px)" rel="alternate"/>
# <meta content="L'ÉQUIPE" property="og:site_name"/>
# <meta content="article" property="og:type"/>
# <meta content="fr_FR" property="og:locale"/>
# <meta content="L'ÉQUIPE - L'actualité du sport en continu." property="og:title"/>
# <meta content="Le sport en direct sur L'EQUIPE.fr. Les informations, résultats et classements de tous les sports. Directs commentés, images et vidéos à regarder et à partager !." property="og:description"/>
# <meta content="https://www.lequipe.fr/" property="og:url"/>
# <meta content="//www.lequipe.fr/elements/svg/logo-lequipe.svg" property="og:image"/>
# <meta content="L'ÉQUIPE - L'actualité du sport en continu." name="twitter:title"/>
# <meta content="Le sport en direct sur L'EQUIPE.fr. Les informations, résultats et classements de tous les sports. Directs commentés, images et vidéos à regarder et à partager !" name="twitter:description"/>
# <meta content="https://www.lequipe.fr/" name="twitter:url"/>
# <meta content="//www.lequipe.fr/elements/svg/logo-lequipe.svg" name="twitter:image"/>
# <meta content="261959740493169" property="fb:app_id"/>
# <meta content="607767138" property="fb:admins"/>
# <meta content="682217508" property="fb:admins"/>
# <meta content="18936161" property="twitter:account_id"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@lequipe" name="twitter:site"/>
# <meta content="76283417065" property="fb:pages"/>
# <link href="/elements/img/favicons/apple-touch-icon-57x57.png?140917" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/elements/img/favicons/apple-touch-icon-60x60.png?140917" rel="apple-touch-icon" sizes="60x60"/>
# <link href="/elements/img/favicons/apple-touch-icon-72x72.png?140917" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/elements/img/favicons/apple-touch-icon-76x76.png?140917" rel="apple-touch-icon" sizes="76x76"/>
# <link href="/elements/img/favicons/apple-touch-icon-114x114.png?140917" rel="apple-touch-icon" sizes="114x114"/>
# <link href="/elements/img/favicons/apple-touch-icon-120x120.png?140917" rel="apple-touch-icon" sizes="120x120"/>
# <link href="/elements/img/favicons/apple-touch-icon-144x144.png?140917" rel="apple-touch-icon" sizes="144x144"/>
# <link href="/elements/img/favicons/apple-touch-icon-152x152.png?140917" rel="apple-touch-icon" sizes="152x152"/>
# <link href="/elements/img/favicons/apple-touch-icon-180x180.png?140917" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/elements/img/favicons/favicon-32x32.png?140917" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/elements/img/favicons/android-chrome-192x192.png?140917" rel="icon" sizes="192x192" type="image/png"/>
# <link href="/elements/img/favicons/favicon-96x96.png?140917" rel="icon" sizes="96x96" type="image/png"/>
# <link href="/elements/img/favicons/favicon-16x16.png?140917" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/elements/img/favicons/manifest.json" rel="manifest"/>
# <link href="//www.lequipe.fr/elements/img/favicons/apple-touch-icon-16x16.png" rel="icon" type="image/x-icon"/>
# <meta content="#ed1c24" name="msapplication-TileColor"/>
# <meta content="/elements/img/favicons/mstile-144x144.png" name="msapplication-TileImage"/>
# <meta content="#ed1c24" name="theme-color"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <link href="/elements/css/style-cch-20181218031945.min.css" rel="stylesheet" type="text/css"/>
# <!--[if lte IE 9]>
#     <link href="/elements/css/ie-cch-20181218031945.min.css" rel="stylesheet" type="text/css" />
# <![endif]-->
# <!--[if (gte IE 6)&(lte IE 8)]>
#     <script src="/elements/js/plugins/selectivizr-min.js"></script>
# <![endif]-->
# <script type="text/javascript">
#   var features = {};
#       features.timeIso = "2018-12-21T15:39:52+0000";
#       features.blockBuying = "1";
#       features.incitativePopin = "1";
#       features.feed = "//iphdata.lequipe.fr/iPhoneDatas/EFR/STD/ALL/";
# </script>
# <script>  porte_ouverte_mpp=0;</script>
# <script>
#     var VEL;
#     var sas_target;
#     var popin;
# </script>
# <script>
#    var idSport="3";
# </script>
# <script>
#         if (typeof(sas_target)=="undefined") {
#             sas_target="lequipe";
#         }
#     </script>
# <script src="/elements/js/0CA20181221134202ADs201812211342024F98d8q4aBxcs.js"></script>
# <script type="text/javascript">
#     var gs_result = "";
#     var parseResponse = function(result) {
#         gs_result = result;
#     };
#     var gsurl = window.location != window.top.location ? document.referrer : window.location;
#     var scriptElt1 = document.createElement("script");
#     scriptElt1.id = "tc_script_999_1";
#     scriptElt1.type = "text/javascript";
#     scriptElt1.src = "//laplace.grapeshot.co.uk/main/channels-jsonp.cgi?url=" + encodeURIComponent(gsurl) + "&callback=parseResponse";
#     scriptElt1.async = true;
#     (document.getElementsByTagName('head')[0] || document.getElementsByTagName('body')[0] || document.getElementsByTagName('script')[0].parentNode).insertBefore(scriptElt1, null);
# </script>
# <script>
#
#             var cmpOptout = false;
#
#             switch(localStorage.getItem('cmpOptout')) {
#               case 'true' :  cmpOptout = true; break;
#               case 'false' : cmpOptout = false; break;
#               default :  cmpOptout = false; break;
#             }
#
#     </script>
# <script async="" src="/elements/js/standalone/prebid_lequipe-cch-20181218031945.js" type="text/javascript"></script>
# <script>
#         /* Nugg.ad - v2 - 201601025 */
#         var nuggtg = encodeURIComponent('sport');
#         var nuggrid = encodeURIComponent(top.location.href);
#         var nuggscr = document.createElement('script');
#         nuggscr.type = 'text/javascript';
#         nuggscr.src ='//lpm-amaury.nuggad.net/rc?nuggn=1218387167&nuggsid=977061605&nuggtg='+nuggtg+'&nuggrid='+nuggrid+'';
#         var n = document.getElementsByTagName('script')[0];
#         n.parentNode.insertBefore(nuggscr, n);
#         /* Fin Nugg.ad */
#     </script>
# <script type="text/javascript">
#         bw_ps_adspot_id = "12374016";
#         if(localStorage) {ps_version = localStorage.getItem('ps_version');}
#         if(typeof ps_version =='undefined' || ps_version == null) {ps_version = new Date().getTime();}
#         document.write('<scr'+'ipt src="https://abs.proxistore.com/abe/js/psuniversaltag.js?v='+ps_version+'" type="text/javascript" async></scr'+'ipt>');
#     </script>
# <script type="text/javascript">
#         var googletag = googletag || {};
#         googletag.cmd = googletag.cmd || [];
#         (function() {
#             var gads = document.createElement("script");
#             gads.async = true;
#             gads.type = "text/javascript";
#             var useSSL = "https:" == document.location.protocol;
#             gads.src = (useSSL ? "https:" : "http:") + "//www.googletagservices.com/tag/js/gpt.js";
#             var node =document.getElementsByTagName("script")[0];
#             node.parentNode.insertBefore(gads, node);
#         })();
#     </script>
# <script src="/elements/js/standalone/ads-cch-20181218031945.js" type="text/javascript"></script>
# <link href="/elements/css/standalone/widget.css?20181218031945" rel="stylesheet"/>
# </head>
# <body ac="" an="" class="ev7 page-home js-home-page " sport="General" type="home_rub">
# <div class="ads DFP DFP--dfp_interstitiel v2 js-ads js-ad--dfp_interstitiel" id="dfp_interstitiel">
# <script type="text/javascript">
#                     googletag.cmd.push(function() { googletag.display("dfp_interstitiel"); });
#                 </script>
# </div>
# <div class="navigation js-navigation ">
# <div class="navigation__toplinks">
# <a href="//www.lequipe.fr">L'Équipe</a>
# <a href="//www.lequipe.fr/Adrenaline/">Adrénaline</a>
# <a href="//www.lequipe.fr/Coaching/">L'Équipe coaching</a>
# <a href="//www.lequipe.fr/Sport-et-style/">Sport&amp;Style</a>
# <a href="//www.lequipe.fr/Velo-mag/">Vélo magazine</a>
# <a href="http://roustantv.lequipe.fr/">Roustan TV</a>
# </div>
# <div class="navigation__home">
# <div class="navigation__home__universe">
# <a class="le-journal" href="/abonnement/kiosque/" title="le journal L'Equipe"></a>
# <a class="la-chaine" href="/lachainelequipe/" title="la chaîne L'Equipe"><span></span></a>
# </div>
# <div class="navigation__logo logo logo--lequipe"><a href="//www.lequipe.fr"></a></div>
# <div class="navigation__home__abopremium js-ctaLanding">
# <a href="//www.lequipe.fr/abonnement/offres/15793?prov=W-HP-BHHPG" onclick="return tag.selfPromotion.send({elem:this,click:{adId:'105',format:'[W-HP-BHHPG]'}});">
# <img alt="Promo Premium" src="/elements/img/premium/bloc_abonnement_oreillette--14767.png"/>
# <div class="navigation__home__abopremium--texte">
# <span>abonnez-vous</span>
# <span>sans engagement</span>
# <span class="grey">1€ pendant 1 mois</span>
# </div>
# </a>
# </div>
# </div>
# <div class="navigation__menu">
# <div class="navigation__menu__home">
# <ul>
# <li>
# <a class="icon icon--house icon--black" href="/" title="L'Equipe"></a>
# </li>
# <li class="Premium onglet-premium ">
# <a class="textLink" href="https://abonnes.lequipe.fr/#decouverte">abonné</a>
# </li>
# <li class="Football"> <a class="textLink" href="/Football/">            Football   </a> </li> <li class="Rugby"> <a class="textLink" href="/Rugby/">            Rugby   </a> </li> <li class="Basket"> <a class="textLink" href="/Basket/">            Basket   </a> </li> <li class="Ski-Glace"> <a class="textLink" href="/Aussi/Ski-glace/">            Ski-Glace   </a> </li> <li class="Handball"> <a class="textLink" href="/Handball/">            Handball   </a> </li> <li class="Tennis"> <a class="textLink" href="/Tennis/">            Tennis   </a> </li> <li class="Basket"> <a class="textLink" href="/Basket/Nba/">            NBA   </a> </li> <li class="Formule1"> <a class="textLink" href="/Formule-1/">            F1   </a> </li> <li class="Golf"> <a class="textLink" href="/Golf/">            Golf   </a> </li> <li class="Cyclisme"> <a class="textLink" href="/Cyclisme/">            Cyclisme   </a> </li> <li class="Athletisme"> <a class="textLink" href="/Athletisme/">            Athlé   </a> </li> <li class="Aussi"> <a class="textLink" href="/Aussi/Volley-ball/">            Volley-ball   </a> </li> <li class="Sports-us"> <a class="textLink" href="/Sports-us/">            Sports US   </a> </li> <li class="Auto-moto"> <a class="textLink" href="/Auto-moto/">            Auto-moto   </a> </li> <li class="Voile"> <a class="textLink" href="/Voile/">            Voile   </a> </li> <li class="Natation"> <a class="textLink" href="/Natation/">            Natation   </a> </li> <li class="Aussi"> <a class="textLink" href="/Aussi/Biathlon/">            Biathlon   </a> </li> <li class="Adrenaline"> <a class="textLink" href="/Adrenaline/">            Adrénaline   </a> </li> <li class="Aussi"> <a class="textLink" href="/Adrenaline/Surf/World-surf-league/">            WSL   </a> </li> <li class="Coaching"> <a class="textLink" href="/Coaching/">            Coaching   </a> </li> <li class="Sport-et-style"> <a class="textLink" href="/Sport-et-style/">            Sport &amp; Style   </a> </li> <li class="Velo-mag"> <a class="textLink" href="/Velo-mag/">            Vélo Magazine   </a> </li> <li class="Aussi"> <a class="textLink" href="/Aussi/Tir/">            Tir   </a> </li> <li class="Aussi"> <a class="textLink" href="/Aussi/Squash/">            Squash   </a> </li> <li class="Aussi"> <a class="textLink" href="/Aussi/Tennis-de-table/">            Tennis de table   </a> </li>
# <li class="Adrenaline"><a href="/Adrenaline/">adrénaline</a></li>
# <li class="Ilosport"><a href="/Coaching/">coaching</a></li>
# <li class="menu__plus"><a class=" js-menu-plus">...</a></li>
# </ul>
# </div>
# <div class="navigation__menu__directres js-directs-resultats">
# <a class="navigation__menu__directres__directs" href="/Directs">
# <span class=" skew skew--red skew--left navigation__menu__directres__directs__title">
#                 directs
#         </span>
# <style>
#             .navigation__menu__directres__directs__nbdirects:before {
#                 display: inline-block;
#                 content: "0";
#                 transform: initial;
#                 padding-left: 0px;
#                 position: relative;
#                 z-index: 1;
#             }
#         </style>
# <span class=" skew skew--livenull skew--right navigation__menu__directres__directs__nbdirects"></span>
# </a>
# <a class="navigation__menu__directres__resultats" href="/Resultats">
# 		résultats
# 	</a>
# <a class="navigation__menu__directres__agenda" href="/programme-tv/agenda.html">
#             programme TV
#         </a>
# <a class="navigation__menu__directres__videos" href="//video.lequipe.fr">
#             vidéos
#         </a>
# </div>
# <div class="navigation__menu__compte-search">
# <div class="navigation__menu__menuright"><a class="icon icon--user icon--black js-account-user">
# <img class="picture-user js-picture-user" src="#"/>
# </a>
# </div>
# <div class="navigation__menu__menuright"><a class="icon icon--search icon--black" href="/recherche/search.php"></a>
# </div>
# <div class="navigation__menu__menuright"><a class="icon icon--burger icon--black js-menu-burger"></a>
# </div>
# </div>
# </div>
# <div class="navigation__menu navigation__menu--sticky">
# <div>
# <div>
# <a class="icon icon--house icon--black" href="/" title="L'Equipe"></a>
# </div>
# <div class="navigation__menu__logo">
# <div class="navigation__logo logo logo--lequipe"><a href="//www.lequipe.fr"></a></div>
# </div>
# <a class="navigation__menu__sport js-libNavSport" href="#"> </a>
# <div class="navigation__menu__plus js-menu-plus">...</div>
# </div>
# <div>
# <div>
# <div class="navigation__menu__directres js-directs-resultats">
# <a class="navigation__menu__directres__directs" href="/Directs">
# <span class=" skew skew--red skew--left navigation__menu__directres__directs__title">
#                 directs
#         </span>
# <style>
#             .navigation__menu__directres__directs__nbdirects:before {
#                 display: inline-block;
#                 content: "0";
#                 transform: initial;
#                 padding-left: 0px;
#                 position: relative;
#                 z-index: 1;
#             }
#         </style>
# <span class=" skew skew--livenull skew--right navigation__menu__directres__directs__nbdirects"></span>
# </a>
# <a class="navigation__menu__directres__resultats" href="/Resultats">
# 		résultats
# 	</a>
# <a class="navigation__menu__directres__agenda" href="/programme-tv/agenda.html">
#             programme TV
#         </a>
# <a class="navigation__menu__directres__videos" href="//video.lequipe.fr">
#             vidéos
#         </a>
# </div>
# </div>
# <div class="navigation__menu__compte-search">
# <div class="navigation__menu__menuright">
# <a class="Premium onglet-premium textLink" href="/abonnement/offres/15793?prov=W-THP-STKY" onclick="return tag.selfPromotion.send({elem:this,click:{adId:'108',format:'[W-THP-STKY]'}});">s'abonner</a>
# </div>
# <div class="navigation__menu__menuright">
# <a class="icon icon--user icon--black js-account-user">
# <img class="picture-user js-picture-user" src="#"/>
# </a>
# </div>
# <div class="navigation__menu__menuright">
# <a class="icon icon--search icon--black" href="/recherche/search.php"></a>
# </div>
# <div class="navigation__menu__menuright">
# <a class="icon icon--burger icon--black js-menu-burger"></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- OUTER EDITO CONTENT -->
# <div class="container" id="outer-edito-content">
# <div class="home container__use js-content">
# <div class="ads DFP DFP--dfp_banniere-haute v2 js-ads js-ad--dfp_banniere-haute" id="dfp_banniere-haute">
# <script type="text/javascript">
#                     googletag.cmd.push(function() { googletag.display("dfp_banniere-haute"); });
#                 </script>
# </div>
# <div data-iab-tag="dfp_banniere_haute"></div>
# <section class="row row--first oreillettes" data-vr-zone="LiensImages">
# <div class="oreillettes__item col " data-vr-contentbox="" rub="Football" sport="36" type="OREILLETTE">
# <a date="" double="0" href="/Football/Directs" onglet="1" quadruple="0" target="_blank" triple="0">
# <div class="oreillettes__image">
# <img alt="" src="https://medias.lequipe.fr/img-photo-jpg/oreillette-v6-5-foot/1500000000288539/0:0,150:90-120-90-75/1ce06.jpg"/>
# </div>
# <div class="oreillettes__block">
# <div class="oreillettes__label">Foot</div>
# <div class="oreillettes__label">Les matches</div>
# </div>
# </a>
# </div><div class="oreillettes__item col " data-vr-contentbox="" rub="Rugby" sport="101" type="OREILLETTE">
# <a date="" double="0" href="/Rugby/Coupe-d-europe/" onglet="0" quadruple="0" triple="0">
# <div class="oreillettes__image">
# <img alt="" src="https://medias.lequipe.fr/img-photo-jpg/oreillette-v-6-5-rugby/1500000000288494/0:0,150:90-120-90-75/2bda4.jpg"/>
# </div>
# <div class="oreillettes__block">
# <div class="oreillettes__label">Rugby</div>
# <div class="oreillettes__label">Coupe d'Europe</div>
# </div>
# </a>
# </div><div class="oreillettes__item col " data-vr-contentbox="" rub="Football" sport="36" type="OREILLETTE">
# <a date="" double="0" href="/Football/Ligue-1/" onglet="0" quadruple="0" triple="0">
# <div class="oreillettes__image">
# <img alt="" src="https://medias.lequipe.fr/img-photo-jpg/oreillette-v-6-5-football/1500000000288595/0:0,150:90-120-90-75/c00cc.jpg"/>
# </div>
# <div class="oreillettes__block">
# <div class="oreillettes__label">Foot</div>
# <div class="oreillettes__label">Ligue 1</div>
# </div>
# </a>
# </div><div class="oreillettes__item col " data-vr-contentbox="" rub="Ski-Glace" sport="51" type="OREILLETTE">
# <a date="" double="0" href="https://www.lequipe.fr/Aussi/Biathlon/" onglet="0" quadruple="" triple="0">
# <div class="oreillettes__image">
# <img alt="" src="https://medias.lequipe.fr/img-photo-jpg/french-martin-fourcade-during-the-mixed-relay-competition-of-the-ibu-biathlon-world-cup-in-pokljuka/1500000001058769/0-120-90-75/9acd6.jpg"/>
# </div>
# <div class="oreillettes__block">
# <div class="oreillettes__label">Biathlon</div>
# <div class="oreillettes__label">Coupe du monde</div>
# </div>
# </a>
# </div>
# </section>
# <div class="row">
# </div>
# <div class="row">
# <div class="col col--x2" data-vr-zone="Actualites">
# <div class="home__lead " data-vr-zone="TitrePrincipal" rub="Football" sport="36" type="UNEGDLEADER">
# <div data-vr-contentbox="">
# <h1 class="home__lead__title title">
# <a href="/Football/Actualites/Rudi-garcia-om-si-j-avais-choisi-la-facilite-je-ne-serais-pas-venu-ici/971072">«Si j'avais choisi la facilité...»</a>
# </h1>
# <a class="home__lead__image" href="/Football/Actualites/Rudi-garcia-om-si-j-avais-choisi-la-facilite-je-ne-serais-pas-venu-ici/971072">
# <div class="tags" partenaire="">
# <div class="tags__element skew skew--first skew--right" jo="JO 2018">
#                     Foot                </div>
# <div class="tags__element skew skew--darkgrey">
#                         L1
#                     </div>
# <div class="tags__element skew skew--midgrey">
#                         OM
#                     </div>
# </div>
# <img alt="«Si j'avais choisi la facilité...»" src="https://medias.lequipe.fr/img-photo-jpg/rudi-garcia-porcu-l-equipe/1500000001068172/17:507,1959:1801-624-416-75/a60f0.jpg"/>
# <span class="icon icon--video icon--big icon--square "></span>
# </a>
# <!-- /base/football/bloc_match/323/428323.html" -->
# <a class="scoring" href="/Football/match-direct/ligue-1/2018-2019/angers-om-live/428323">
# <div class="scoring__team">
# <img alt="Angers Logo" class="scoring__team__logo js-lazy" data-src="//medias.lequipe.fr/logo-football/374/30-alt-20181218031945" src="//www.lequipe.fr/v6/img/SVG-EFR.svg"/>
# <div class="scoring__team__name">Angers</div>
# </div>
# <div class="scoring__digits">
# <div class="scoring__digits__date">Demain</div>
# <div class="clear"></div>
# <div class="scoring__digits__element scoring__digits__element--solo">21h00</div>
# </div>
# <div class="scoring__team scoring__team__right">
# <div class="scoring__team__name">Marseille</div>
# <img alt="Marseille Logo" class="scoring__team__logo js-lazy" data-src="//medias.lequipe.fr/logo-football/6/30-alt-20181218031945" src="//www.lequipe.fr/v6/img/SVG-EFR.svg"/>
# </div>
# </a>
# <a href="/Football/Actualites/Rudi-garcia-om-si-j-avais-choisi-la-facilite-je-ne-serais-pas-venu-ici/971072">
# <p class="home__lead__details">
#     Trente-six heures après l'élimination en Coupe de la Ligue, l'entraîneur de l'OM Rudi Garcia a continué d'afficher son optimisme.
# </p></a>
# <div class="home__lead__links">
# <a class="home__colead__links__element" href="/Football/Actualites/Om-les-chiffres-de-la-mauvaise-passe/970881">
#                 Les chiffres de la mauvaise passe
#                             </a>
# </div>
# </div>
# </div>
# <div class="ads DFP DFP--dfp_banniere-flux-autopromo v2 js-ads js-ad--dfp_banniere-flux-autopromo" id="dfp_banniere-flux-autopromo">
# <script type="text/javascript">
#                     googletag.cmd.push(function() { googletag.display("dfp_banniere-flux-autopromo"); });
#                 </script>
# </div>
# <div class="home__colead split " data-vr-contentbox="" rub="Football" sport="36">
# <a class="home__colead__image" href="/Football/Actualites/Thomas-tuchel-psg-il-n-y-a-pas-de-cassure-avec-rabiot/971002">
# <div class="tags" partenaire="">
# <div class="tags__element skew skew--first skew--right" jo="JO 2018">
#                     Foot                </div>
# <div class="tags__element skew skew--darkgrey">
#                         L1
#                     </div>
# <div class="tags__element skew skew--midgrey">
#                         PSG
#                     </div>
# </div>
# <img alt="Tuchel : «Pas de cassure avec Rabiot»" class="js-lazy" data-src="https://medias.lequipe.fr/img-photo-jpg/tuchel-ne-compte-pas-sur-rabiot-pour-le-moment-a-mounic-l-equipe/1500000001068076/0:0,2000:1333-304-202-75/f1273.jpg" src="//static.lequipe.fr/v6/img/SVG-EFR.svg"/>
# <span class="icon icon--video icon--big icon--square "></span>
# </a>
# <div class="home__colead__split">
# <a href="/Football/Actualites/Thomas-tuchel-psg-il-n-y-a-pas-de-cassure-avec-rabiot/971002">
# <h2 class="home__colead__title title title--xxs">
#
#             Tuchel : «Pas de cassure avec Rabiot»
#
# </h2><p class="home__colead__details">
#     L'entraîneur du PSG Thomas Tuchel a assuré que la mise à l'écart d'Adrien Rabiot était un choix sportif.
# </p> </a>
# <div class="home__colead__links">
# <a class="home__colead__links__element" href="/Football/Article/Ce-que-le-psg-a-economise-en-ne-prolongeant-pas-adrien-rabiot-depuis-2014/970424" onclick="return tag.selfPromotion.send({elem:this,click:{adId:'39',format:'[Ce_que_le_psg_a_economise_en_ne_prolongeant_pas_adrien_rabiot_depuis_2014]'}});">
#                 Ce que Rabiot n'a pas coûté au PSG
#                                     <span class="premium">abonné</span>
# </a>
# <a class="home__colead__links__element" href="/Football/Actualites/Veronique-rabiot-la-decision-d-adrien-rabiot-de-quitter-le-psg-est-ferme-et-definitive/970381">
#                 La décision de Rabiot est «ferme et définitive»
#                             </a>
# </div>
# </div> </div>
# <script>
#             var ctaNameId = '';
#             typeof atnameID != 'undefined' ? ctaNameId = '_' + atnameID : ctaNameId = '';
#         </script>
# <div class="offer js-ctaLanding">
# <div class="offer__bloc">
# <h2 class="offer__title">
# </h2><p class="offer__highlight">offre solidarité</p>
# <p class="offer__details offer__details--strong">1 abonnement acheté* = 1€ reversé au</p>
# <img alt="" class="offer__image" src="/common/img/offers/paywall/2018/offre-fondaction.png"/>
# <a class="button button--big button--yellow" href="//www.lequipe.fr/abonnement/offres/15793?prov=W-HP-LBAN&amp;returnurl=/" onclick="return tag.selfPromotion.send({elem:this,click:{adId:'104',format:'[W-HP-LBAN'+ctaNameId+']'}});">je m'abonne pour 1€</a>
# <p class="offer__mentions">
#
#                         * opération valable du 1er au 31 décembre pour tout nouvel abonnement, voir conditions
#
#                 </p>
# </div>
# </div>
# <div class="home__colead split " data-vr-contentbox="" rub="Ski-Glace" sport="63">
# <a class="home__colead__image" href="/Ski/Actualites/Geant-de-courchevel-tessa-worley/971024">
# <div class="tags" partenaire="">
# <div class="tags__element skew skew--first skew--right" jo="JO 2018">
#                     Ski alpin                </div>
# <div class="tags__element skew skew--darkgrey">
#                         CM (F)
#                     </div>
# </div>
# <img alt="Un podium pour Worley, Shiffrin intouchable" class="js-lazy" data-src="https://medias.lequipe.fr/img-photo-jpg/pour-son-retour-tessa-worley-a-signe-un-podium-a-courchevel-s-boue-sebastien/1500000001068116/0-304-202-75/ca863.jpg" src="//static.lequipe.fr/v6/img/SVG-EFR.svg"/>
# </a>
# <div class="home__colead__split">
# <a href="/Ski/Actualites/Geant-de-courchevel-tessa-worley/971024">
# <h2 class="home__colead__title title title--xxs">
#
#             Un podium pour Worley, Shiffrin intouchable
#
# </h2><p class="home__colead__details">
#     Trois semaines après sa dernière course, en raison d'un genou douloureux, Tessa Worley termine 3e du géant de Courchevel. Shiffrin s'impose devant Rebensburg.
# </p> </a>
# <div class="home__colead__links">
# <a class="home__colead__links__element" href="/Ski/Actualites/Tessa-worley-tres-contente-de-cette-troisieme-place-au-geant-de-courchevel/971057">
#                 Worley : «Très contente»
#                             </a>
# <a class="home__colead__links__element" href="/Ski/SkiClassementEpreuve1832.html">
#                 Classement
#                             </a>
# </div>
# </div> </div>
# <div class="ads DFP DFP--dfp_banniere-flux-1 v2 js-ads js-ad--dfp_banniere-flux-1" id="dfp_banniere-flux-1">
# <script type="text/javascript">
#                     googletag.cmd.push(function() { googletag.display("dfp_banniere-flux-1"); });
#                 </script>
# </div>
# <div class="folder football" data-vr-zone="Dossier-Football" rub="Football" sport="36" type="DOSSIER">
# <div class="tags">
# <div class="tags__element tags__element--lg skew skew--right " jquery="text" json="titresport">Foot</div>
# <div class="tags__element tags__element--lg skew skew--darkgrey" jquery="text" json="titre[].texte">Ligue 1</div>
# <div class="tags__element tags__element--lg skew skew--midgrey" jquery="text" json="titre[].texte">Transferts</div>
# </div>
# <div class="colsort">
# <div class="home__colead " data-vr-contentbox="" rub="Football" sport="36">
# <a class="home__colead uni" href="/Football/Diaporama/Le-point-sur-les-mercatos-d-ete-a-la-mi-saison/7275">
# <h2 class="home__colead__title title title--xs">
#
#             Notre bilan du mercato à mi-saison
#
# </h2>
# <div class="home__colead__image">
# <div class="tags" partenaire="">
# </div>
# <img alt="Notre bilan du mercato à mi-saison" class="js-lazy" data-src="https://medias.lequipe.fr/img-photo-jpg/laborde-gaetan/1500000001042347/600:175,1746:939-624-416-75/791d6.jpg" src="//static.lequipe.fr/v6/img/SVG-EFR.svg"/>
# <span class="icon icon--pic icon--xl icon--square"></span>
# </div>
# <p class="home__colead__details">
#     En septembre, L'Équipe avait attribué une note aux clubs de L1 pour leurs transferts estivaux. À la mi-saison, le bilan des reporters témoigne des excellents mercatos de Lille et Montpellier. En bas, Monaco a tout faux.
# </p></a>
# </div>
# <div class="home__colead split " data-vr-contentbox="" rub="Football" sport="36">
# <a class="home__colead__image" href="/Football/Article/Transferts-les-bonnes-affaires-du-mercato/970985" onclick="return tag.selfPromotion.send({elem:this,click:{adId:'37',format:'[Transferts_les_bonnes_affaires_du_mercato]'}});">
# <div class="tags" partenaire="">
# <div class="tags__element skew skew--left skew--premium">abonné</div>
# </div>
# <img alt="Joueurs à saisir" class="js-lazy" data-src="https://medias.lequipe.fr/img-photo-jpg/samir-nasri-leban-l-equipe/1500000001068063/0:0,2000:1333-304-202-75/1469f.jpg" src="//static.lequipe.fr/v6/img/SVG-EFR.svg"/>
# </a>
# <div class="home__colead__split">
# <a href="/Football/Article/Transferts-les-bonnes-affaires-du-mercato/970985" onclick="return tag.selfPromotion.send({elem:this,click:{adId:'37',format:'[Transferts_les_bonnes_affaires_du_mercato]'}});">
# <h2 class="home__colead__title title title--xxs">
#
#             Joueurs à saisir
#
# </h2><p class="home__colead__details">
#     Le marché des transferts s'ouvre le 1er janvier. Voici une liste de de bonnes affaires potentielles.
# </p> </a>
# <div class="home__colead__links">
# <a class="home__colead__links__element" href="/Football/Article/Pas-de-droit-a-l-erreur-pour-monaco-et-marseille-pendant-le-mercato-hivernal/970901" onclick="return tag.selfPromotion.send({elem:this,click:{adId:'39',format:'[Pas_de_droit_a_l_erreur_pour_monaco_et_marseille_pendant_le_mercato_hivernal]'}});">
#                 Pas de droit à l'erreur
#                                     <span class="premium">abonné</span>
# </a>
# </div>
# </div> </div>
# <div class="home__colead split " data-vr-contentbox="" rub="Football" sport="36">
# <a class="home__colead__image" href="/Football/Actualites/Regis-dupont-la-bonne-pioche-pour-l-olympique-lyonnais-ce-serait-pepe/970795">
# <div class="tags" partenaire="">
# </div>
# <img alt="«Pepe serait la bonne pioche pour l'OL»" class="js-lazy" data-src="https://medias.lequipe.fr/img-photo-jpg/-/1500000001067644/108:0,1728:1080-304-202-75/02e26.jpg" src="//static.lequipe.fr/v6/img/SVG-EFR.svg"/>
# <span class="icon icon--video icon--big icon--square "></span>
# </a>
# <div class="home__colead__split">
# <a href="/Football/Actualites/Regis-dupont-la-bonne-pioche-pour-l-olympique-lyonnais-ce-serait-pepe/970795">
# <h2 class="home__colead__title title title--xxs">
#
#             «Pepe serait la bonne pioche pour l'OL»
#
# </h2><p class="home__colead__details">
#     L'ouverture du mercato hivernal pourrait permettre à l'OL de recruter un défenseur central qui lui manque. Pourquoi pas le Portugais Pepe.
# </p> </a>
# </div> </div>
# <div class="home__colead " data-vr-contentbox="" rub="Football" sport="36">
# <a class="home__colead " href="/Football/Article/Florian-thauvin-devrait-quitter-l-om-l-ete-prochain/970837" onclick="return tag.selfPromotion.send({elem:this,click:{adId:'36',format:'[Florian_thauvin_devrait_quitter_l_om_l_ete_prochain]'}});">
# <div class="home__colead__image">
# <div class="tags" partenaire="">
# <div class="tags__element skew skew--first skew--right">
#                         OM                    </div>
# <div class="tags__element skew skew--left skew--premium">abonné</div>
# </div>
# <img alt="Thauvin sur la fin" class="js-lazy" data-src="https://medias.lequipe.fr/img-photo-jpg/thauvin-sur-la-fin/1500000001067755/0-624-416-75/2c342.jpg" src="//static.lequipe.fr/v6/img/SVG-EFR.svg"/>
# </div>
# <h2 class="home__colead__title title title--xs">
#
#             Thauvin sur la fin
#
# </h2>
# <p class="home__colead__details">
#     La vente du champion du monde, cet été, apparaît fort probable. D'une manière générale, les dirigeants se préparent à renouveler l'effectif.
# </p></a>
# <div class="home__colead__links">
# <a class="home__colead__links__element" href="/Football/Actualites/Om-les-chiffres-de-la-mauvaise-passe/970881">
#                 Les chiffres de la mauvaise passe
#                             </a>
# <a class="home__colead__links__element" href="/Football/Article/Crises-en-serie-a-l-om/970796" onclick="return tag.selfPromotion.send({elem:this,click:{adId:'39',format:'[Crises_en_serie_a_l_om]'}});">
#                 Un OM au bord de la crise de nerfs
#                                     <span class="premium">abonné</span>
# </a>
# </div>
# </div>
# <div class="home__colead split " data-vr-contentbox="" rub="Football" sport="36">
# <a class="home__colead__image" href="/Football/Article/La-plan-secret-des-dirigeants-nantais-pour-vendre-emiliano-sala/970811" onclick="return tag.selfPromotion.send({elem:this,click:{adId:'37',format:'[La_plan_secret_des_dirigeants_nantais_pour_vendre_emiliano_sala]'}});">
# <div class="tags" partenaire="">
# <div class="tags__element skew skew--first skew--right">
#                         Nantes                    </div>
# <div class="tags__element skew skew--left skew--premium">abonné</div>
# </div>
# <img alt="Sala, le plan secret" class="js-lazy" data-src="https://medias.lequipe.fr/img-photo-jpg/sala-le-plan-secret/1500000001067691/0-304-202-75/9e063.jpg" src="//static.lequipe.fr/v6/img/SVG-EFR.svg"/>
# </a>
# <div class="home__colead__split">
# <a href="/Football/Article/La-plan-secret-des-dirigeants-nantais-pour-vendre-emiliano-sala/970811" onclick="return tag.selfPromotion.send({elem:this,click:{adId:'37',format:'[La_plan_secret_des_dirigeants_nantais_pour_vendre_emiliano_sala]'}});">
# <h2 class="home__colead__title title title--xxs">
#
#             Sala, le plan secret
#
# </h2><p class="home__colead__details">
#     Les dirigeants nantais négocient discrètement avec Cardiff pour le transfert du meilleur buteur de L1, qu'Halilhodzic souhaite voir prolonger.
# </p> </a>
# </div> </div>
# <div class="home__colead split " data-vr-contentbox="" rub="Football" sport="36">
# <a class="home__colead__image" href="/Football/Article/Courtise-nicolas-pepe-n-est-pas-presse-de-quitter-lille/970861" onclick="return tag.selfPromotion.send({elem:this,click:{adId:'37',format:'[Courtise_nicolas_pepe_n_est_pas_presse_de_quitter_lille]'}});">
# <div class="tags" partenaire="">
# <div class="tags__element skew skew--first skew--right">
#                         Lille                    </div>
# <div class="tags__element skew skew--left skew--premium">abonné</div>
# </div>
# <img alt="Pépé, l'envol pas pressé" class="js-lazy" data-src="https://medias.lequipe.fr/img-photo-jpg/pepe-l-envol-pas-presse/1500000001067824/0-304-202-75/df377.jpg" src="//static.lequipe.fr/v6/img/SVG-EFR.svg"/>
# </a>
# <div class="home__colead__split">
# <a href="/Football/Article/Courtise-nicolas-pepe-n-est-pas-presse-de-quitter-lille/970861" onclick="return tag.selfPromotion.send({elem:this,click:{adId:'37',format:'[Courtise_nicolas_pepe_n_est_pas_presse_de_quitter_lille]'}});">
# <h2 class="home__colead__title title title--xxs">
#
#             Pépé, l'envol pas pressé
#
# </h2><p class="home__colead__details">
#     Suivi par de prestigieux clubs européens, l'attaquant lillois entend d'abord, comme ses dirigeants, finir la saison dans le Nord.
# </p> </a>
# </div> </div>
# <div class="home__colead " data-vr-contentbox="" rub="Football" sport="36">
# <a class="home__colead " href="/Football/Article/Un-agent-mandate-par-chelsea-a-pris-contact-avec-l-entourage-de-nabil-fekir/970839" onclick="return tag.selfPromotion.send({elem:this,click:{adId:'36',format:'[Un_agent_mandate_par_chelsea_a_pris_contact_avec_l_entourage_de_nabil_fekir]'}});">
# <div class="home__colead__image">
# <div class="tags" partenaire="">
# <div class="tags__element skew skew--first skew--right">
#                         Lyon                    </div>
# <div class="tags__element skew skew--left skew--premium">abonné</div>
# </div>
# <img alt="Fekir, Zahavi s'en mêle" class="js-lazy" data-src="https://medias.lequipe.fr/img-photo-jpg/fekir-nabil/1500000001067763/0:100,1690:1225-624-416-75/8aa56.jpg" src="//static.lequipe.fr/v6/img/SVG-EFR.svg"/>
# </div>
# <h2 class="home__colead__title title title--xs">
#
#             Fekir, Zahavi s'en mêle
#
# </h2>
# <p class="home__colead__details">
#     Le super-agent israélien Pini Zahavi, mandaté par Chelsea, a pris contact avec l'entourage du capitaine lyonnais.
# </p></a>
# <div class="home__colead__links">
# <a class="home__colead__links__element" href="/Football/Article/Cet-hiver-lyon-cherchera-des-defenseurs-centraux/970833" onclick="return tag.selfPromotion.send({elem:this,click:{adId:'39',format:'[Cet_hiver_lyon_cherchera_des_defenseurs_centraux]'}});">
#                 Lyon attaque l'arrière
#                                     <span class="premium">abonné</span>
# </a>
# <a class="home__colead__links__element" href="/Football/Article/Pas-de-droit-a-l-erreur-pour-monaco-et-marseille-pendant-le-mercato-hivernal/970901" onclick="return tag.selfPromotion.send({elem:this,click:{adId:'39',format:'[Pas_de_droit_a_l_erreur_pour_monaco_et_marseille_pendant_le_mercato_hivernal]'}});">
#                 Pas de droit à l'erreur
#                                     <span class="premium">abonné</span>
# </a>
# </div>
# </div>
# <div class="home__colead split " data-vr-contentbox="" rub="Football" sport="36">
# <a class="home__colead__image" href="/Football/Article/Pas-de-droit-a-l-erreur-pour-monaco-et-marseille-pendant-le-mercato-hivernal/970901" onclick="return tag.selfPromotion.send({elem:this,click:{adId:'37',format:'[Pas_de_droit_a_l_erreur_pour_monaco_et_marseille_pendant_le_mercato_hivernal]'}});">
# <div class="tags" partenaire="">
# <div class="tags__element skew skew--left skew--premium">abonné</div>
# </div>
# <img alt="Pas de droit à l'erreur" class="js-lazy" data-src="https://medias.lequipe.fr/img-photo-jpg/pas-de-droit-a-l-erreur/1500000001067904/0:0,960:640-304-202-75/679ba.jpg" src="//static.lequipe.fr/v6/img/SVG-EFR.svg"/>
# </a>
# <div class="home__colead__split">
# <a href="/Football/Article/Pas-de-droit-a-l-erreur-pour-monaco-et-marseille-pendant-le-mercato-hivernal/970901" onclick="return tag.selfPromotion.send({elem:this,click:{adId:'37',format:'[Pas_de_droit_a_l_erreur_pour_monaco_et_marseille_pendant_le_mercato_hivernal]'}});">
# <h2 class="home__colead__title title title--xxs">
#
#             Pas de droit à l'erreur
#
# </h2><p class="home__colead__details">
#     Après une phase aller sombre, Monaco et Marseille sont dans l'obligation de réussir leur mercato hivernal. Pour les autres clubs de L 1, et même pour le PSG, lancé dans sa quête d'un milieu défensif, cela s'annonce plus calme.
# </p> </a>
# </div> </div>
# <div class="home__colead split " data-vr-contentbox="" rub="Football" sport="36">
# <a class="home__colead__image" href="/Football/Actualites/Nice-patrick-vieira-evoque-l-echec-mario-balotelli/970968">
# <div class="tags" partenaire="">
# <div class="tags__element skew skew--first skew--right">
#                         Nice                    </div>
# </div>
# <img alt="Vieira évoque «l'échec» Balotelli" class="js-lazy" data-src="https://medias.lequipe.fr/img-photo-jpg/vieira-balotelli-cela-ne-fonctionne-pas-l-equipe/1500000001068031/221:318,1623:1253-304-202-75/86cf7.jpg" src="//static.lequipe.fr/v6/img/SVG-EFR.svg"/>
# </a>
# <div class="home__colead__split">
# <a href="/Football/Actualites/Nice-patrick-vieira-evoque-l-echec-mario-balotelli/970968">
# <h2 class="home__colead__title title title--xxs">
#
#             Vieira évoque «l'échec» Balotelli
#
# </h2><p class="home__colead__details">
#     L'entraîneur de Nice, Patrick Vieira, évoque le départ de Mario Balotelli, qu'il qualifie «d'échec».
# </p> </a>
# <div class="home__colead__links">
# <a class="home__colead__links__element" href="/Football/Article/Mario-balotelli-pourrait-quitter-nice-des-cet-hiver/970805" onclick="return tag.selfPromotion.send({elem:this,click:{adId:'39',format:'[Mario_balotelli_pourrait_quitter_nice_des_cet_hiver]'}});">
#                 Balotelli vers la sortie
#                                     <span class="premium">abonné</span>
# </a>
# <a class="home__colead__links__element" href="/Football/Article/Boudebouz-et-maouassa-dans-le-viseur-de-nice-cet-hiver/970860" onclick="return tag.selfPromotion.send({elem:this,click:{adId:'39',format:'[Boudebouz_et_maouassa_dans_le_viseur_de_nice_cet_hiver]'}});">
#                 Boudebouz et Maouassa dans le viseur
#                                     <span class="premium">abonné</span>
# </a>
# </div>
# </div> </div>
# <div class="home__colead " data-vr-contentbox="" rub="Football" sport="36">
# <a class="home__colead " href="/Football/Article/Sur-le-point-de-perdre-adrien-rabiot-paris-a-besoin-de-milieux/970894" onclick="return tag.selfPromotion.send({elem:this,click:{adId:'36',format:'[Sur_le_point_de_perdre_adrien_rabiot_paris_a_besoin_de_milieux]'}});">
# <div class="home__colead__image">
# <div class="tags" partenaire="">
# <div class="tags__element skew skew--first skew--right">
#                         PSG                    </div>
# <div class="tags__element skew skew--left skew--premium">abonné</div>
# </div>
# <img alt="Embrouille au milieu" class="js-lazy" data-src="https://medias.lequipe.fr/img-photo-jpg/embrouille-au-milieu/1500000001067880/0-624-416-75/7d06c.jpg" src="//static.lequipe.fr/v6/img/SVG-EFR.svg"/>
# </div>
# <h2 class="home__colead__title title title--xs">
#
#             Embrouille au milieu
#
# </h2>
# <p class="home__colead__details">
#     Orphelin de Thiago Motta cet été et sur le point de perdre Adrien Rabiot, le PSG a un besoin urgent dans l'entrejeu, même si ses moyens sont limités.
# </p></a>
# <div class="home__colead__links">
# <a class="home__colead__links__element" href="/Football/Article/Pas-de-droit-a-l-erreur-pour-monaco-et-marseille-pendant-le-mercato-hivernal/970901" onclick="return tag.selfPromotion.send({elem:this,click:{adId:'39',format:'[Pas_de_droit_a_l_erreur_pour_monaco_et_marseille_pendant_le_mercato_hivernal]'}});">
#                 Pas de droit à l'erreur
#                                     <span class="premium">abonné</span>
# </a>
# <a class="home__colead__links__element" href="/Football/Article/Weah-adli-et-dagba-les-titis-du-psg-qui-vont-bouger-lors-du-mercato-d-hiver/970896" onclick="return tag.selfPromotion.send({elem:this,click:{adId:'39',format:'[Weah_adli_et_dagba_les_titis_du_psg_qui_vont_bouger_lors_du_mercato_d_hiver]'}});">
#                 Les «titis» vont bouger
#                                     <span class="premium">abonné</span>
# </a>
# <a class="home__colead__links__element" href="/Football/Actualites/Psg-neymar-deja-en-vacances-et-absent-contre-nantes/970898">
#                 Neymar en vacances et absent contre Nantes
#                             </a>
# </div>
# </div>
# <div class="home__colead split " data-vr-contentbox="" rub="Football" sport="36">
# <a class="home__colead__image" href="/Football/Article/Cette-fois-les-verts-ne-vont-pas-bouger-pendant-le-mercato-d-hiver/970823" onclick="return tag.selfPromotion.send({elem:this,click:{adId:'37',format:'[Cette_fois_les_verts_ne_vont_pas_bouger_pendant_le_mercato_d_hiver]'}});">
# <div class="tags" partenaire="">
# <div class="tags__element skew skew--first skew--right">
#                         Saint-Etienne                    </div>
# <div class="tags__element skew skew--left skew--premium">abonné</div>
# </div>
# <img alt="Cette fois, les Verts ne vont pas bouger" class="js-lazy" data-src="https://medias.lequipe.fr/img-photo-jpg/cette-fois-les-verts-ne-vont-pas-bouger/1500000001067733/0-304-202-75/2d666.jpg" src="//static.lequipe.fr/v6/img/SVG-EFR.svg"/>
# </a>
# <div class="home__colead__split">
# <a href="/Football/Article/Cette-fois-les-verts-ne-vont-pas-bouger-pendant-le-mercato-d-hiver/970823" onclick="return tag.selfPromotion.send({elem:this,click:{adId:'37',format:'[Cette_fois_les_verts_ne_vont_pas_bouger_pendant_le_mercato_d_hiver]'}});">
# <h2 class="home__colead__title title title--xxs">
#
#             Cette fois, les Verts ne vont pas bouger
#
# </h2><p class="home__colead__details">
#     Contrairement à l'an passé où ils avaient rebâti une équipe dans l'urgence, les Stéphanois ne veulent pas chambouler leur effectif cet hiver.
# </p> </a>
# <div class="home__colead__links">
# <a class="home__colead__links__element" href="/Football/Article/L-asse-hesite-a-vendre-robert-beric-en-fin-de-contrat-l-ete-prochain/970820" onclick="return tag.selfPromotion.send({elem:this,click:{adId:'39',format:'[L_asse_hesite_a_vendre_robert_beric_en_fin_de_contrat_l_ete_prochain]'}});">
#                 Le hic, c'est Beric
#                                     <span class="premium">abonné</span>
# </a>
# </div>
# </div> </div>
# <div class="home__colead " data-vr-contentbox="" rub="Football" sport="36">
# <a class="home__colead " href="/Football/Article/Mercato-hivernal-monaco-veut-se-renforcer-dans-chaque-ligne/970791" onclick="return tag.selfPromotion.send({elem:this,click:{adId:'36',format:'[Mercato_hivernal_monaco_veut_se_renforcer_dans_chaque_ligne]'}});">
# <div class="home__colead__image">
# <div class="tags" partenaire="">
# <div class="tags__element skew skew--first skew--right">
#                         Monaco                    </div>
# <div class="tags__element skew skew--left skew--premium">abonné</div>
# </div>
# <img alt="Opération Fabregas" class="js-lazy" data-src="https://medias.lequipe.fr/img-photo-jpg/chelsea-s-cesc-fabregas/1500000001067766/0:190,1755:1360-624-416-75/43023.jpg" src="//static.lequipe.fr/v6/img/SVG-EFR.svg"/>
# </div>
# <h2 class="home__colead__title title title--xs">
#
#             Opération Fabregas
#
# </h2>
# <p class="home__colead__details">
#     Pour assurer son maintien, l'AS Monaco cherche des renforts dans chaque ligne. Ancien partenaire de Thierry Henry à Arsenal, le milieu de terrain espagnol est sa cible prioritaire.
# </p></a>
# <div class="home__colead__links">
# ...
# <div id="pictos-content">
# <a class="foo-compte" href="/mon-compte/">compte</a>
# <a class="foo-rss" href="/rss/">rss</a>
# <a class="foo-newsletter" href="/mon-compte/mes-newsletters" rel="nofollow">newsletter</a>
# <a class="foo-plan" href="/Fonctions/navs-plan-du-site.html">plan du site</a>
# <a class="foo-credits" href="/Fonctions/pages_credits.html" target="_blank">crédits</a>
# <a class="foo-cgu" href="/Fonctions/cgu.html">CGU</a>
# <a class="foo-mentions" href="/Fonctions/mentions-legales.html">mentions légales</a>
# <a class="foo-privacy" href="/Fonctions/politique-confidentialite.html">politique de confidentialité</a>
# <a class="foo-cookies" href="/cookies/">cookies</a>
# <a class="foo-contacts" href="/Fonctions/page_contacts.html">contacts</a>
# </div>
# </div>
# <div class="row row--colored baseline-content">
# <div class="amaury-content" id="amaury-content">
# <div>
# <a href="http://www.francefootball.fr/" rel="nofollow" target="_blank">FranceFootball</a> |
#             <a href="https://www.lequipe.fr/Adrenaline/" rel="nofollow" target="_blank">Adrénaline L'Équipe</a> |
#             <a href="https://www.lequipe.fr/Coaching/" rel="nofollow" target="_blank">L'Équipe Coaching</a> |
#             <a href="http://www.lequipemagazine.fr/" rel="nofollow" target="_blank">L'Équipe Magazine</a> |
#             <a href="https://www.lequipe.fr/Velo-mag/" rel="nofollow" target="_blank">Vélo Magazine</a> |
#             <a href="https://www.lequipe.fr/Sport-et-style/" rel="nofollow" target="_blank">Sport &amp; Style</a> |
#             <a href="http://www.aso.fr/" rel="nofollow" target="_blank">ASO</a> |
#             <a href="http://www.amaurymedias.fr/" rel="nofollow" target="_blank">Amaury Media</a> |
#             <a href="http://www.pressesports.com/" rel="nofollow" target="_blank">PresseSports</a> |
#             <a href="http://www.amaury.com/" rel="nofollow" target="_blank">Groupe Amaury</a> |
#             <a href="https://codepromo.lequipe.fr" target="_blank">Code promo</a> <span>© L'Equipe 24/24 -
#         2018
#         <br/>tous droits réservés</span>
# </div>
# </div>
# </div>
# </footer>
# <a class="backtotop js-backtotop"><span class="icon icon--medium icon--backtop"></span></a>
# <!--[if lt IE 9]>
#         <div class="oldie">
#     <div class="oldie__container">
#         <a href="#" class="icon icon--cross" onclick="document.getElementsByClassName('oldie')[0].parentNode.removeChild(document.getElementsByClassName('oldie')[0])"></a>
#         <p>
#             Vous utilisez une ancienne version d’Internet Explorer pour laquelle le site L'Équipe n’est plus optimisé.
#             <br/> Pour une utilisation optimale, merci de télécharger la dernière version d’IE en cliquant <a href="https://www.microsoft.com/fr-fr/download/internet-explorer.aspx">ici</a> ou d'utiliser Chrome ou Firefox.
#         </p>
#     </div>
# </div>
#     <![endif]-->
# </body>
# <script type="text/javascript">var popin=new Object();</script>
# <!-- SCRIPTS -->
# <script type="text/javascript">
# 	//sas_pageid = '(none)';
# 	//sas_target = '';
# 	//sas_blocked = false;
# </script>
# <div id="analyzer">
# <!-- DOCUMENT_URI == /v7-lequipe/dist/patterns/home.html -->
# <!-- REQUEST_URI == / -->
# <!-- tag_edito_lib == general -->
# <!-- code_web == WTF -->
# <script>
#                 atchapter1 = s17 = 'general';
#                 atchapter1 = s17 = atchapter1.toLowerCase().replace('elit1','top_14').replace('top14','top_14').replace('elit2','pro-d2').replace(/\-/g, "_");//.replace('d1','ligue-1').replace('d2','ligue-2')
#             </script>
# <div id="analyzer">
# <script>
#                 var at_docUri = '/v7-lequipe/dist/patterns/home.html';
#                 var at_repUrlUri = '/v7-lequipe/dist/patterns/home.html'.split('/')[3];
#                 var taggage = 'ON';
#             </script>
# </div>
# </div>
# <script src="/elements/js/scripts-cch-20181218031945.min.js"></script>
# <script async="">
#     (function createWeboramaPixel () {
#         var connectedInfosCookie = getCookie('lequipe-connected-infos');
#         var cryptedEmail = connectedInfosCookie ? JSON.parse(connectedInfosCookie).email_sha : '';
#         var pixel = document.createElement('img');
#         pixel.height = 1;
#         pixel.width = 1;
#         pixel.src = "https://redirect.frontend.weborama.fr/redirect/standard?url=https%3A%2F%2Fstags.bluekai.com%2Fsite%2F54472%3Flimit%3D1%26phint%3De_id_s%253D" +
#             cryptedEmail +
#             "%26phint%3Dusr_id%253D{WEBO_CID}​%26phint%3Dwebsite%253Dl_equipe";
#         document.body.appendChild(pixel);
#     })();
# </script>
# <!--[if lte IE 9]>
# <script>
#     $(document).ready(function(){
#         $('.js-content').css('margin-left', ($(window).width() - 960) / 2 -20);
#         $('.js-content').css('width', '960px');
#         $('.oreillettes,.oreillettes__item').remove();
#     });
# </script>
# <![endif]-->
# <!--[if lte IE 8]>
# <script>
#     $(document).ready(function(){
#         $('.logo--lequipe').css('background-image', 'url(/elements/img/ie/logo-lequipe.png)');
#         $('.navigation__menu--sticky').remove();
#
#         $('.navigation__menu__home').css('width','100%');
#         $('.navigation__menu__home ul li').css('margin','0 5px');
#         $('.navigation__menu__compte-search').remove();
#          $('.menu__plus').remove();
#
#
#
#
#        /*
#         $('.le-journal').addClass('ie-le-journal').removeClass('le-journal');
#         $('.la-chaine').addClass('ie-la-chaine').removeClass('la-chaine');
#         */
#     });
# </script>
# <![endif]-->
# <!-- BEGIN weborama -->
# <iframe src="//cstatic.weborama.fr/iframe/customers/premium.html?idEditeur=1176&amp;idSite=260" style="height:1px;width:1px;border:0 none;position:absolute;display:none;left:0;top:0;z-index:0"></iframe>
# <!-- END weborama -->
# <script type="application/ld+json">
#         {
#             "@context": "http://schema.org",
#             "@type": "WebSite",
#             "url": "https://www.lequipe.fr/",
#             "potentialAction": {
#                 "@type": "SearchAction",
#                 "target": "https://www.lequipe.fr/recherche/search.php?r={search_term_string}",
#                 "query-input": "required name=search_term_string"
#             }
#         }
#     </script>
# <script>
#     /* YOU SHOULD NOT EDIT THIS PART */
#     !function(a,b,c){"use strict";function d(a){var b=e[c]||{};e[c]=b,b[a]||(b[a]=function(){e._queue[c].push({method:a,args:Array.prototype.slice.apply(arguments)})})}var e=a.scimhtiraidem||{},f="init call config push pushDefault addProperties addProperty onFinish onStart _reset".split(" ");e._queue=e._queue||{},e._names=e._names||[],e._names.push(c),e._queue[c]=e._queue[c]||[],e._startTime=(new Date).getTime(),e._snippetVersion="2.0";for(var g=0;g<f.length;g++)d(f[g]);a.scimhtiraidem=e,a[c]=e[c];var h=b.createElement("script");h.setAttribute("type","text/javascript"),h.setAttribute("src","//static.mediarithmics.com/tag/1/tag.min.js"),h.setAttribute("async","true"),b.getElementsByTagName("script")[0].parentNode.appendChild(h)}(window,document,"gravity");
#
#     /* CUSTOM */
#     gravity.init({
#         mode: "VISIT",
#         site_token: "leq-web17"
#     });
#     var dr_properties = {};
#     if (typeof s18 !== "undefined" && s18!== "") {dr_properties["s18"] = s18;}; // Sport
#     if (typeof s17 !== "undefined" && s17!== "") {dr_properties["s17"] = s17;}; // Competition
#     if (typeof s29 !== "undefined" && s29!== "") {dr_properties["s29"] = s29;}; // Keywords redaction
#     if (typeof s28 !== "undefined" && s28!== "") {dr_properties["s28"] = s28;}; // Type de page
#     if (typeof s27 !== "undefined" && s27!== "") {dr_properties["s27"] = s27;}; // Presence video
#     if (typeof s26 !== "undefined" && s26!== "") {dr_properties["s26"] = s26;}; // Presence photo
#     gravity.push("$page_view", dr_properties);
# </script>
# <script>var pulpixId=715;!function(e,t){var i=t.createElement("script"),r=t.getElementsByTagName("script")[0];i.src="https://cdn.pulpix.com/static/pulpix.js",i.id="pulpix",i.async=true,i.setAttribute("data-user-id",pulpixId),r.parentNode.insertBefore(i,r)}(window,document);</script>
# <script src="/elements/js/standalone/mediametrie.js"></script>
# <script type="text/javascript">
#             if (typeof s28=="string" && typeof s18=="string") {
#                 (function () {
#                     top.ONFOCUS = {
#                         app_id:'10301',
#                         app_domain:'ufo/uopsgevpmd/gcj4m2e84kg63e',
#                         ad_query_selector:'div[id^=dfp]',
#                         ad_get_id: function(e){return e.id},
#                         ad_get_name: function(e){return e.id.slice(4);},
#                         pagetype:s28,
#                         category:s18.replace(/\-/g, "_").replace(/\ /g, "_"),
#                         tag_s:new Date().getTime()
#                     };
#                     (function(x, u, h){h=function(s){return s.split('').map(function(c){return String.fromCharCode(c.charCodeAt(0)-1)}).reverse().join(''); };x=new XMLHttpRequest();x.open('GET',top.window.location.protocol+'//'+ h(top.ONFOCUS.app_domain)+'/d');x.onreadystatechange=function(){if(x.readyState===x.DONE && x.status===200 && x.responseText){u = h(x.responseText).split(',');u=(top.window.location.protocol==='http:')?'http://'+u[0]:'https://'+u[1];(function(f,d,a,b){b=top.document.createElement('iframe');b.src='javascript:false',(b.frameElement||b).style.cssText='width: 0; height: 0; border: 0; display:none;';a=top.document.getElementsByTagName('script')[0];a.parentNode.insertBefore(b,a);try{d=b.contentWindow.document;}catch(c){f=top.document.domain;b.src="javascript:var d=document.open();d.domain='"+f+"';void(0);";d=b.contentWindow.document;}d.open()._l=function(){var e=this.createElement('script');f&&(this.domain=f);e.id='boomr-if-as';e.src=u+'/'+top.ONFOCUS.app_id+'/b.js';this.body.appendChild(e);};d.write('<body onload="document._l();">');d.close();}());}};x.send();}());
#                 })();
#             }
#     </script>
# <script async="async" src="//widgets.outbrain.com/outbrain.js"></script>
# <script src="//cdn.tagcommander.com/4284/tc_LEQUIPE_21.js" type="text/javascript"></script>
# <script type="text/javascript">
#     var __cmp = __cmp || null
#     function setCmpOptout(answer = true) {
#         localStorage.setItem("cmpOptout", JSON.stringify(answer));
#     }
#     if (__cmp && getCookie('cmpLequipe') === "") {
#         setTimeout(function() {
#             __cmp('getVendorConsents', null, function(result, success) {
#                 var purposeConsent = Object.values(result.purposeConsents);
#                 var hasConsent = true;
#                 for (var i = 0; i < purposeConsent.length; i++) {
#                     if (!purposeConsent[i]) {
#                         hasConsent = false;
#                         break;
#                     }
#                 }
#                 console.log('setCmpOpt POPIN', hasConsent);
#                 setCmpOptout(hasConsent);
#                 createCookie('cmpLequipe', '1', 1000);
#             });
#         }, 5000);
#
#         document.addEventListener('scroll', function(e) {
#             if (getCookie('cmpLequipeAction') === "") {
#                 createCookie('cmpLequipeAction', '1', 1000);
#                 console.log('setCmpOpt SCROLL');
#                 setCmpOptout(true);
#             }
#         });
#         document.addEventListener('click', function(e) {
#             if (getCookie('cmpLequipeAction') === "") {
#                 createCookie('cmpLequipeAction', '1', 1000);
#                 console.log('setCmpOpt CLICK');
#                 setCmpOptout(true);
#             }
#         });
#     }
# </script>
# <script>
#     (function(w,d,s,i,n){w[n]=w[n]||{q:[],init:function(o){w[n].initOpts=o;},ready:function(c){w[n].q.push(c);}};
#         setTimeout(function(j,k){if(!d.getElementById(i)){k=d.getElementsByTagName(s)[0];j=d.createElement(s);j.id=i;
#             j.src="https://cdn.by.wonderpush.com/sdk/1.1/wonderpush-loader.min.js";k.parentNode.insertBefore(j,k);}},0);
#     }(window,document,"script","wonderpush-jssdk-loader","WonderPush"));
#     WonderPush.init({
#         webKey: "57a61e98b452199f6555f0fcc3f69935a1880a92ee39d6e466ab79e8f3e5243d",
#         manifestUrl: "/elements/img/favicons/manifest.json",
#         plugins: {
#             "optin-dialog": {
#                 triggers: {
#                     snooze: 30*24*60*60*1000,
#                     minPages: 3
#                 },
#                 hidePoweredBy: true,
#                 title: "Recevez nos informations urgentes en temps réel et ne manquez rien de l'actu sportive",
#                 message: "Vous pourrez vous désinscrire à tout moment.",
#                 positiveButton: "Activer",
#                 negativeButton: "Plus tard",
#                 icon: "https://m.lequipe.fr/img/favicons/favicon-96x96.png",
#                 style: {
#                     position: "fixed",
#                     zIndex: 1000000
#                 }
#             }
#         }
#     });
#     WonderPush.ready(function(WonderPushSDK) {
#         WonderPushSDK.getInstallationCustomProperties().then(function(custom) {
#             if (!("string_subscriptions" in custom)) {
#                 return WonderPushSDK.putInstallationCustomProperties({
#                     string_subscriptions: ["InfoGenerales"]
#                 });
#             }
#         });
#     });
# </script>
# <script async="" src="//radar.cedexis.com/1/10044/radar.js"></script>
# <script src="/elements/js/standalone/widget.js?20181218031945" type="text/javascript"></script>
# </html>

# %% [markdown]
# Nous avons ainsi récupérer les informations du site sans les enregistrer physiquement dans un fichier, uniquement dans une variable !
#
# Réafficher le titre principal, les sous titres des articles ainsi que leurs descriptions pour vous en persuader

# %%
soup = BeautifulSoup(html_doc)
# Dans mon fichier (lequipe.fr) en regardant ce script html Nous pouvons voir que les sous titres sont rangés 
# dans la balise h2
for p in soup.find_all('h1'):
    print (p.text)
# Out:
# Avec la finale de Coupe Davis en tête

# %%
soup = BeautifulSoup(html_doc)
# Dans mon fichier (lequipe.fr) en regardant ce script html Nous pouvons voir que les sous titres sont rangés 
# dans la balise h2
for p in soup.find_all('h2'):
    print (p.text.strip())
# Out:
# Les tops et flops des Français de l'étranger
# Avez-vous bien suivi le week-end européen ?
# Martial régale
#
# Mannarino - Humbert en direct
# Hadzibegic remplace Brouard
# Brunel pas convaincu par les remplacements sur blessure
# Une belle semaine en Bleu
# Comment ils situent Hamilton
# Le roi Mbappé a un nouveau dauphin
# Depay, un drôle de cas
# Un record pour Paris, Lille et Montpellier enchaînent
# Ronaldo justifie son départ du Real
# Dans les bagages de Nicolas Troussel
# la chaine L’Équipe
# 2018, la saison noire de Tsonga
# «Humbert n'arrive pas en novice»
# Sock, une saison en enfer
# Toulon coule, Clermont déroule
# L'OL en hausse
# L'équipe type du week-end
# Une vie en dehors des paddocks
# Le carnet de notes de Mexico
# Hamilton : «C'est surréaliste»
# Le cinquième titre de Hamilton en images
# Le débrief du match
# Mbappé : «Une grande équipe se repose sur des leaders»
# Garcia : «Si un jour le VAR est mis en route...»
# OM-PSG en vidéos
# Gobert et Okobo se montrent encore
# Golden State enchaîne, Oklahoma City gagne enfin
# Les 5 infos de la semaine à retenir
# Qui sont vos joueurs de la semaine ?
# Le propriétaire est mort dans le crash
# Los Angeles et Detroit se rebiffent
# Les Boston Red Sox champions
# New Orleans a pris sa revanche
# Qui est votre champion du week-end ?
# Paris brûle t-il ? waterloo de la l1, et clasico..
# Loeb : «La discipline pour laquelle je suis fait»
# L'actu du sport en vidéo
# Baroque et classique
# Mbappé, puni, vidi, vici
# Nsoki, le «titi» a du répondant
# Une attaque sans tête
# Les plus belles images de la Red Bull Rampage
# Rheeder, première victoire
# Les Golden Trail Series, le futur du trail running ?
# Crepel : «Jaws, c'était de la folie»
# Les plus belles rénovations de stades
# Les nouvelles tenues de l'équipe de France
# La montre de Ronaldo vaut 2 millions d'euros
# Les 10 plus beaux maillots de la C1
# 4 boissons chaudes healthy et gourmandes
# 11 postures utiles après un long trajet
# 10 comptes féminins de yoga à suivre
# Comment avoir un ventre plat avec le régime Fodmap ?
# Des solutions pour éviter les accidents de chasse
# Les nouvelles tendances du vélo et du VTT
# Des vélos pour aider au développement
# Robert Leroy, le prêtre cycliste et compétiteur
#
# Quand le golf devient fou
#
#
# Revivez la Coupe du monde 1998

# %%
soup = BeautifulSoup(html_doc)
# Dans mon fichier (lequipe.fr) en regardant ce script html Nous pouvons voir que les sous titres sont rangés 
# dans la balise h2
for p in soup.find_all('p'):
    print (p.text.strip())
# Out:
# Une grosse dizaine de joueurs français peut prétendre à la finale de la Coupe Davis (23-25 novembre). Si pour certains la sélection semble une évidence, pour les autres, le Rolex Paris Masters sera le dernier moment pour se montrer.
# Anthony Martial a encore régalé ce week-end. Pour Raphaël Varane et Benjamin Pavard, notamment, il a viré au cauchemar.
# Le carton du Barça lors du Clasico face au Real, la performance de Cristiano Ronaldo avec la Juventus, le choc Naples-Roma, la terrible série de Newcastle, etc. Avez-vous bien suivi le week-end européen ?
# Auteur de son quatrième but en trois matches de Premier League, l'attaquant français a confirmé son retour en forme.
# 1€
# puis 9,99€/mois sans engagement
# offre valable du 23 au 31 octobre 2018
#                     * voir conditions
# Adrian mannarino, 46e mondial, entre en lice contre Ugo Humbert, bénéficiaire d'une invitation. A suivre ensuite Richard Gasquet et Nicolas Mahut. Les matches en scoring.
# Après avoir annoncé la suspension de Régis Brouard comme entraîneur, le Red Star a annoncé lundi l'arrivée de Faruk Hadzibegic.
# La nouvelle règle des quatre remplacements supplémentaires sur blessure, testée cette saison en Top 14 et Pro D2 afin de protéger la santé des joueurs, «dérange un peu» Jacques Brunel, le sélectionneur du XV de France.
# La majorité des joueurs français a brillé la semaine dernière en NBA. Avec une mention pour Rudy Gobert et Elie Okobo.
# Quatre anciens champions du monde évaluent Lewis Hamilton au regard de ses glorieux aînés.
# Entré en cours de jeu à Marseille (0-2), l'attaquant parisien n'a pas mis longtemps pour signer sa 10e réalisation de la saison. Et asseoir un peu plus sa suprématie au classement des buteurs.
# Mécontent de ne pas avoir été titularisé à Angers, l'international néerlandais de l'OL payait son attitude à Hoffenheim, mardi, pendant et après le match.
# Lille et Montpellier restent les lointains poursuivants du PSG, auteur d'un 11e succès en onze matches, à Marseille. En fond de classement, Monaco ne décolle pas. Le bilan du week-end.
# Dans un entretien accordé à France Football, Cristiano Ronaldo, l'attaquant de la Juventus Turin, a expliqué qu'il avait quitté le Real Madrid, l'été dernier, car il ne se sentait plus considéré.
# Pour la Route du Rhum, quelques sacs sont embarqués pour répondre à toutes les problématiques.
# Le Manceau est de retour au Rolex Paris Masters après une saison gâchée par les blessures.
# Cédric Raynaud, entraîneur d'Ugo Humbert, évoque le premier tour de son jeune joueur contre Adrian Mannarino aujourd'hui.
# Jack Sock va défendre son titre au Rolex Paris Masters. Une entreprise bien difficile pour un joueur qui n'a remporté que sept matches cette saison.
# Alors que Toulon et Perpignan restent scotchés en fond de classement, Clermont et le Stade Français continuent de briller. Le bilan du week-end.
# L'Olympique Lyonnais a grimpé de sept places dans le classement des clubs ayant formé le plus de joueurs actuellement présents dans 31 premières divisions européennes, passant de la 21e à la 14e place. Dans les cinq grands Championnats, le centre de formation de l'OL est deuxième.
# Chaque lundi, nous déterminons l'équipe type des meilleurs joueurs français du week-end, qu'ils jouent en Ligue 1 ou à l'étranger. Cette semaine, on y retrouve Paul Pogba et Kylian Mbappé, mais aussi Dayot Upamecano, Nicolas Benezet et Sébastien Haller.
# Le Britannique, sacré champion du monde de F1 pour la cinquième fois, sait aussi s'occuper loin des circuits.
# Qui a brillé ce dimanche à Mexico ? Qui s'est loupé ? Retrouvez notre carnet de notes du Grand Prix du Mexique... avec plus ou moins de bonne foi.
# Lewis Hamilton avait du mal à mettre des mots sur ses émotions après une course difficile, dimanche à Mexico, qui s'est conclue par son cinquième titre mondial.
# Lewis Hamilton a décroché son cinquième titre de champion du monde grâce à sa victoire dimanche à Mexico. Revivez en images la saison du pilote britannique.
# Jean-Philippe Durand et Mickaël Madar débriefent la victoire du PSG à Marseille (2-0).
# L'attaquant du PSG, buteur face à Marseille après être entré en jeu, assure être capable d'assumer le rôle de leader.
# L'entraîneur marseillais peinait à digérer la faute sifflée contre Kevin Strootman, qui a privé son équipe de l'égalisation (86e).
# Déjà en vue lors du match précédent, Rudy Gobert, avec Utah, et Elie Okobo, avec Phoenix, ont confirmé avec de nouvelles bonnes performances.
# Golden State a signé une quatrième victoire consécutive, en battant Brooklyn (120-114) dimanche, tandis qu'Oklahoma City a enfin décroché un succès, face à Phoenix (117-110).
# Toronto et Milwaukee invincibles, Stephen Curry qui claque 51 points, Tyronn Lue congédié à Cleveland... Retrouvez les infos les plus marquantes de la semaine écoulée.
# Comme chaque lundi, venez voter pour le joueur NBA qui vous a le plus impressionné dans chaque conférence la semaine passée.
# Le propriétaire de Leicester, Vichai Srivaddhanaprabha, est mort dans l'accident d'hélicoptère survenu samedi, sur le parking du King Power Stadium, après le match contre West Ham.
# Mal en point en ce début de saison, les Los Angeles Kings et les Detroit Red Wings l'ont emporté, respectivement face aux NY Rangers (4-3) et à Dallas (4-2).
# A l'issue d'une victoire large (5-1) chez les Los Angeles Dodgers lors du match 5, les Boston Red Sox ont remporté les World Series pour la neuvième fois de leur histoire.
# Dix mois après leur défaite crève-coeur en play-offs, les New Orleans Saints ont cette fois battu les Minnesota Vikings sur leur terrain (30-20). Les LA Rams sont toujours invaincus.
# Roger Federer, Lewis Hamilton, Sébastien Loeb, Tessa Worley et Elina Svitolina ont brillé ce week-end. Votez pour celui ou celle qui vous a le plus impressionné.
# Venu pour une pige, Sébastien Loeb se réjouit de sa victoire en Catalogne. Et n'exclut plus de rempiler la saison prochaine.
# Le Paris-SG a disposé comme d'habitude de l'OM dans un Classique marqué par les choix forts des deux entraineurs et une grosse erreur d'arbitrage.
# Le sacre de Brett Rheeder, des tricks de haut vol, le podium avec Andreu Lacondeguy et Ethan Nell... Revivez en images la Red Bull Rampage 2018 dans le désert poussiéreux de l'Utah. La compétition de VTT considérée comme la plus spectaculaire du monde.
# Si le FC Barcelone et le Real Madrid ont prévu de rénover leurs enceintes de manière significative, d'autres clubs avant eux sont déjà passés à l'acte. Zoom sur les plus belles rénovations de stades.
# Un peu trop accro au café latte ? Voici notre sélection de boissons healthy et gourmandes, dans lesquelles la caféine est remplacée par de bons nutriments. Une bonne façon de se faire plaisir avec un latte, en apportant de bonnes choses à notre organisme.
# La MBF (Moutain Bikers Foundation) a réagi au décès d'un vététiste suite à un accident de chasse en proposant des solutions pour améliorer la sécurité des deux parties.
# Voici notre guide complet des 30  franchises de la NBA, avant le début de la saison régulière, le 16 octobre.
# Des tribunes pleines, des chants, des cris: le départ de la Ryder Cup se déroule toujours dans une atmosphère indescriptible pour les golfeurs.
# Découvrez dans ce nouvel Equipe Explore les légendaires matches de Grand Chelem que Roger Federer a disputés pour devenir, sans doute, le plus grand joueur de tous les temps.
# Ce travail, réalisé par les élèves de l’Ecole de journalisme de Sciences-Po, a remporté le IVe Prix Explore.
